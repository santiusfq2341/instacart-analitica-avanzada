# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
crudo_ordenes = pd.read_csv('instacart_orders.csv', sep=';')

# %%
crudo_ordenes.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
#
#    days_since_prior_order
# 0                    30.0
# 1                     9.0
# 2                     2.0
# 3                    10.0
# 4                    17.0

# %%
crudo_ordenes.query('user_id == 183418')
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0        1515936   183418            11          6                 13
# 236116    566564   183418            23          0                  8
# 419182   1861906   183418            16          6                 10
# 428409    642049   183418            25          2                  9
#
#         days_since_prior_order
# 0                         30.0
# 236116                     9.0
# 419182                    27.0
# 428409                     6.0

# %%
crudo_ordenes.query('user_id == 163593')
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 1        1690866   163593             5          5                 12
# 136792     60739   163593            17          6                 13
# 409286   3077764   163593            12          6                  7
# 449641   2691848   163593            15          3                  8
#
#         days_since_prior_order
# 1                          9.0
# 136792                     9.0
# 409286                     4.0
# 449641                     7.0

# %%
crudo_ordenes['user_id'].value_counts()
# Out:
# user_id
# 149605    28
# 193164    26
# 78375     25
# 148162    24
# 66664     24
#           ..
# 84143      1
# 49239      1
# 60017      1
# 133649     1
# 132824     1
# Name: count, Length: 157437, dtype: int64

# %%
crudo_ordenes.query('user_id == 193164').sort_values('order_number')
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 240711    192043   193164             5          2                 12
# 447044    826729   193164             9          2                 11
# 387419   2051889   193164            12          5                 14
# 117865   2302763   193164            13          1                 10
# 308325   3184720   193164            14          5                 14
# 168505   1204116   193164            16          1                 17
# 61018    1746856   193164            18          2                 12
# 35009    1891169   193164            29          2                 16
# 255039    659377   193164            31          4                 10
# 117994   2403078   193164            32          5                 14
# 129580   3021238   193164            33          4                 10
# 375335    422798   193164            34          4                 13
# 129883   2244641   193164            37          3                 13
# 330965    829458   193164            43          4                  8
# 115100   1434357   193164            44          1                 16
# 448687   3335747   193164            49          1                 10
# 114950   2483359   193164            50          1                  8
# 304532   2740394   193164            53          4                 10
# 447648   3067920   193164            63          3                 12
# 385781   1544561   193164            71          1                 15
# 447538   3331358   193164            72          3                 12
# 471350   2245855   193164            74          1                 13
# 117459   1800100   193164            82          1                 17
# 219992    710381   193164            83          3                 11
# 167937    463463   193164            88          1                 10
# 451136   1706104   193164            91          2                 15
#
#         days_since_prior_order
# 240711                     4.0
# 447044                     8.0
# 387419                     3.0
# 117865                     3.0
# 308325                    18.0
# 168505                     3.0
# 61018                      6.0
# 35009                      1.0
# 255039                     6.0
# 117994                     1.0
# 129580                     6.0
# 375335                     0.0
# 129883                     7.0
# 330965                     2.0
# 115100                     4.0
# 448687                     4.0
# 114950                     7.0
# 304532                     1.0
# 447648                     1.0
# 385781                     3.0
# 447538                     2.0
# 471350                     3.0
# 117459                     5.0
# 219992                     2.0
# 167937                     7.0
# 451136                     4.0

# %%
crudo_ordenes['user_id'].value_counts().plot(
    kind='hist',
    title='Distribucion de ordenes x usuario',
    xlabel='Total de ordenes',
    ylabel='Total de usuario'
)
plt.show()

# %%
crudo_ordenes
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0        1515936   183418            11          6                 13
# 1        1690866   163593             5          5                 12
# 2        1454967    39980             4          5                 19
# 3        1768857    82516            56          0                 20
# 4        3007858   196724             2          4                 12
# ...          ...      ...           ...        ...                ...
# 478962   3210681     5617             5          1                 14
# 478963   3270802   112087             2          3                 13
# 478964    885349    82944            16          2                 11
# 478965    216274     4391             3          3                  8
# 478966   2071924     1730            18          1                 14
#
#         days_since_prior_order
# 0                         30.0
# 1                          9.0
# 2                          2.0
# 3                         10.0
# 4                         17.0
# ...                        ...
# 478962                     7.0
# 478963                     6.0
# 478964                     6.0
# 478965                     8.0
# 478966                    15.0
#
# [478967 rows x 6 columns]

# %%
crudo_ordenes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
crudo_ordenes[crudo_ordenes.duplicated()]
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# 411408   1286742   183220            48          3                  2
# 415163   2282673    86751            49          3                  2
# 441599   2125197    14050            48          3                  2
#
#         days_since_prior_order
# 145574                     2.0
# 223105                    30.0
# 230807                    16.0
# 266232                     NaN
# 273805                     6.0
# 284038                     7.0
# 311713                     9.0
# 321100                    18.0
# 323900                     7.0
# 345917                     NaN
# 371905                    10.0
# 394347                     2.0
# 411408                     4.0
# 415163                     2.0
# 441599                     3.0

# %%
total_repetidos = crudo_ordenes.duplicated().sum()

# %%
print(f'El total de filas repetidas es: {total_repetidos}')
# Out:
# El total de filas repetidas es: 15

# %%
crudo_ordenes.query('order_id == 1021560')
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 242618   1021560    53767             3          3                  2
# 311713   1021560    53767             3          3                  2
#
#         days_since_prior_order
# 242618                     9.0
# 311713                     9.0
